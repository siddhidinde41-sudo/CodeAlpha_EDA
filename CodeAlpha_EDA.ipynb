# %%
pip install pandas matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in ./.local/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in ./.local/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: seaborn in ./.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.22.4 in ./.local/lib/python3.10/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas) (2025.3)
# Requirement already satisfied: packaging>=20.0 in ./.local/lib/python3.10/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=3 in ./.local/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in ./.local/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.10/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = pd.read_csv("/home/wlug/Downloads/gender_submission.csv")

# Display first 5 rows
print("First 5 Rows:")
print(df.head())

# Dataset Information
print("\nDataset Info:")
print(df.info())

# Column Names
print("\nColumns:")
print(df.columns.tolist())

# Missing Values
print("\nMissing Values:")
print(df.isnull().sum())

# Statistical Summary
print("\nStatistical Summary:")
print(df.describe())

# Correlation Matrix
print("\nCorrelation Matrix:")
print(df.corr(numeric_only=True))

# -----------------------------
# Visualizations
# -----------------------------

# Survival Count
if 'Survived' in df.columns:
    plt.figure(figsize=(5,4))
    sns.countplot(x='Survived', data=df)
    plt.title("Survival Count")
    plt.show()

# Gender Count
if 'Sex' in df.columns:
    plt.figure(figsize=(5,4))
    sns.countplot(x='Sex', data=df)
    plt.title("Gender Distribution")
    plt.show()

# Passenger Class
if 'Pclass' in df.columns:
    plt.figure(figsize=(5,4))
    sns.countplot(x='Pclass', data=df)
    plt.title("Passenger Class")
    plt.show()

# Age Distribution
if 'Age' in df.columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df['Age'].dropna(), bins=30, kde=True)
    plt.title("Age Distribution")
    plt.show()

# Fare Distribution
if 'Fare' in df.columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df['Fare'])
    plt.title("Fare Distribution")
    plt.show()

# Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# First 5 Rows:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB
# None
#
# Columns:
# ['PassengerId', 'Survived']
#
# Missing Values:
# PassengerId    0
# Survived       0
# dtype: int64
#
# Statistical Summary:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000
#
# Correlation Matrix:
#              PassengerId  Survived
# PassengerId     1.000000 -0.023245
# Survived       -0.023245  1.000000

# %%
CodeAlpha_EDA
